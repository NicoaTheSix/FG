# %% [markdown]
# RL設定
# 本篇是參考[logguardq](https://github.com/umbertogs/logguardq)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from collections import deque
import random
import scipy.stats as stats
from scipy.signal import savgol_filter
import re
import shlex
import time

# %% [markdown]
# #### 運算功能
#
# 為了避免過大或過小的數值有額外做一些處理

# %%
def tanh(x):
    return np.tanh(x)

# %% [markdown]
# #### 實際運轉

# %%
def runSimulation():
    return
def evaluateStatisticalSignificance():
    return

# %% [markdown]
# #### 環境設定
# 關於RL如何載入環境除了使用嵌入模型以外也需要考量到Audit Log的紀錄長怎樣
# SAGA的個別檔案則是如以下所示:
# dict_keys(['srcNode', 'dstNode', 'relation', 'timestamp', 'label'])
# - 'srcNode'
#     - 'UUID',
#     - 'Name',
#     - 'Image'
#     - 'Cmdline'
#     - 'Type'
#     - 'Pid'
# - 'dstNode'
# - 'relation'
# - 'timestamp'
# - 'label' (當然這個在訓練完測試的時刻會先刪掉)

# %%
class AuditLogEvironment:
   def __init__(self,logFile="G16.json",size=100):
        self.size=size
        self.stateDim=100 #狀態的維度
        self.actionDim=10 #動作的維度
        return 
   def loadLogs():
      return
   def extractFeaturess():
      return
   def isAnomaly():
      return
   def reset():
      return
   def getState():
      return
   def step():
      return
   def updateNote():
      return

# %% [markdown]
# #### 強化學習的模型設定

# %%
class LogGuardQ:
    def __init__(self, *args, **kwargs):
        super(CLASS_NAME, self).__init__(*args, **kwargs)
    def chooseAction():
        return
    def updataWeight():
        return
class DQN:
    def __init__():
        return
    def forward():
        return
class PPO:
    def __init__(self):
        pass
    def chooseAction():
        return
    def forward():
        return
    def reportDetection():
        return
